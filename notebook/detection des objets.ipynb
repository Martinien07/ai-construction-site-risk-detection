# %% [markdown]
# Architecture globale de l’inférence
#
# Flux logique étape par étape
#
# Code Python complet (un seul pipeline clair)
#
# Où interviennent les seuils (YAML / DB)
#
# Insertion en base de données
#
# Sorties produites (images + métadonnées)

# %% [markdown]
# Entrée
#
# Vidéo (.mp4, .avi, etc.)
#
# Modèle : best_yolo11x.pt
#
# Configuration des seuils :
#
# caméra → site → défaut YAML
#
# Sortie
#
# Images extraites (5 FPS)
#
# Images annotées (bbox, classe, track_id)
#
# Insertion des objets détectés en base
#
#
#
# Vidéo
#  └── Extraction frames (5 FPS)
#       └── YOLO + tracking
#            └── Filtrage par seuil de confiance
#                 └── Attribution track_id
#                      ├── Sauvegarde image
#                      ├── Sauvegarde image annotée
#                      └── Insertion base de données

# %% [markdown]
# 3.1 Imports et paramètres

# %%
import cv2
import yaml
import json
import time
from pathlib import Path
from ultralytics import YOLO
import mysql.connector

# %%
! pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 2.8 MB/s eta 0:00:05
#      -- ------------------------------------- 0.8/11.9 MB 2.1 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.3/11.9 MB 1.8 MB/s eta 0:00:06
#      ------ --------------------------------- 1.8/11.9 MB 2.1 MB/s eta 0:00:05
#      ------- -------------------------------- 2.4/11.9 MB 2.2 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/11.9 MB 2.1 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.1/11.9 MB 2.1 MB/s eta 0:00:05
#      ------------ --------------------------- 3.7/11.9 MB 2.2 MB/s eta 0:00:04
#      -------------- ------------------------- 4.2/11.9 MB 2.2 MB/s eta 0:00:04
# ...
